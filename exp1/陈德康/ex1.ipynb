# %%
import pandas as pd
from pandas import DataFrame
import numpy as np

primitive_data=pd.read_csv("data.csv", encoding='gbk')
primitive_data
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1113      1129        546        上海       网络核心    2050      502     石家庄
# 1114      1129        514        上海       网络核心    2473      946      吉林
# 1115     36036        499        长春       一般节点    1257      178      上海
# 1116     36422        346        天津       网络核心    1997       41      天津
# 1117      2701        619        大连       网络核心    2549     1070      沈阳
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1113     网络核心  48731433404  1.000000e+11
# 1114     一般节点  50060666120  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
# 1116     网络核心  50628787089  1.000000e+11
# 1117     网络核心  48753971761  1.000000e+11
#
# [1118 rows x 10 columns]

# %%
primitive_data_1=primitive_data.dropna(how='any')
primitive_data_1
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1113      1129        546        上海       网络核心    2050      502     石家庄
# 1114      1129        514        上海       网络核心    2473      946      吉林
# 1115     36036        499        长春       一般节点    1257      178      上海
# 1116     36422        346        天津       网络核心    1997       41      天津
# 1117      2701        619        大连       网络核心    2549     1070      沈阳
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1113     网络核心  48731433404  1.000000e+11
# 1114     一般节点  50060666120  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
# 1116     网络核心  50628787089  1.000000e+11
# 1117     网络核心  48753971761  1.000000e+11
#
# [1118 rows x 10 columns]

# %%
data_before_filter=primitive_data_1
data_after_filter_1=data_before_filter.loc[data_before_filter["traffic"]!=0]
data_after_filter_2=data_after_filter_1.loc[data_after_filter_1["from_level"]=='一般节点']
data_after_filter_2
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1097      2473       1460        吉林       一般节点     591      586      绥化
# 1103     36036         18        长春       一般节点    3443      650      青岛
# 1104        63          6        通辽       一般节点   36036       20      长春
# 1107     36036         52        长春       一般节点    1129      171      上海
# 1115     36036        499        长春       一般节点    1257      178      上海
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1097     一般节点  48409925693  1.000000e+11
# 1103     网络核心  48663350759  1.000000e+11
# 1104     一般节点  50355678076  1.000000e+11
# 1107     网络核心  49345226162  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
#
# [550 rows x 10 columns]

# %%
data_before_sample = data_after_filter_2
columns = data_before_sample.columns

weight_sample = data_before_sample.copy()
weight_sample['weight'] = 0

for i in weight_sample.index:
    if weight_sample.at[i, 'to_level'] == '一般节点':
        weight = 1
    else:
        weight = 5
    weight_sample.at[i, 'weight'] = weight

weight_sample_finish = weight_sample.sample(n=50, weights='weight')
weight_sample_finish = weight_sample[columns]
weight_sample_finish
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1097      2473       1460        吉林       一般节点     591      586      绥化
# 1103     36036         18        长春       一般节点    3443      650      青岛
# 1104        63          6        通辽       一般节点   36036       20      长春
# 1107     36036         52        长春       一般节点    1129      171      上海
# 1115     36036        499        长春       一般节点    1257      178      上海
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1097     一般节点  48409925693  1.000000e+11
# 1103     网络核心  48663350759  1.000000e+11
# 1104     一般节点  50355678076  1.000000e+11
# 1107     网络核心  49345226162  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
#
# [550 rows x 10 columns]

# %%
random_sample=data_before_sample
random_sample_finish=random_sample.sample(n=50)
random_sample_finish=random_sample_finish[columns]
random_sample_finish
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 421        591        502        绥化       一般节点     180      264    呼和浩特
# 161        591       1266        绥化       一般节点     235     1950      北京
# 42          96        123      呼和浩特       一般节点    2841      237      郑州
# 931       4069       1205        宁波       一般节点    1997      466      天津
# 157        591       1106        绥化       一般节点   36036      939      长春
# 724       4069       1205        宁波       一般节点   36036       52      长春
# 980       4360        472        南京       一般节点      63      286      通辽
# 86         180        226      呼和浩特       一般节点   36036       20      长春
# 173        787        307        玉溪       一般节点    4953      686      贵阳
# 174        787        316        玉溪       一般节点    1257      177      上海
# 542         63         10        通辽       一般节点    4360      472      南京
# 416        591         60        绥化       一般节点     180       52    呼和浩特
# 154        591       1080        绥化       一般节点     235     1621      北京
# 64         180         18      呼和浩特       一般节点    1536       26    鄂尔多斯
# 644         47        314        通辽       一般节点      96      152    呼和浩特
# 398        474       1291       哈尔滨       一般节点    1756     1018      北京
# 447        787         63        玉溪       一般节点   36036       54      长春
# 1035     36036         54        长春       一般节点     591       23      绥化
# 669         63        286        通辽       一般节点    3227      468      济南
# 109        474        671       哈尔滨       一般节点    2549      919      沈阳
# 304         63        230        通辽       一般节点    3227       77      济南
# 388        474        678       哈尔滨       一般节点      96      124    呼和浩特
# 125        474       1374       哈尔滨       一般节点    2050      336     石家庄
# 16          47        427        通辽       一般节点    1997      213      天津
# 315         96        117      呼和浩特       一般节点    1257      581      上海
# 280         47        243        通辽       一般节点    3213      562      重庆
# 50          96        155      呼和浩特       一般节点    1536      681      广州
# 40          96        117      呼和浩特       一般节点    2050      505     石家庄
# 375        474        422       哈尔滨       一般节点    3213      587      重庆
# 167        787         51        玉溪       一般节点    4561     1033      成都
# 380        474        474       哈尔滨       一般节点    3227      701      济南
# 371        474        360       哈尔滨       一般节点    3227      530      济南
# 1086     36539       1140        杭州       一般节点     235     1661      北京
# 1018       474        672       哈尔滨       一般节点    1756      585      北京
# 939         63          6        通辽       一般节点    2050      269     石家庄
# 91         180        264      呼和浩特       一般节点      63       70      通辽
# 291         47        427        通辽       一般节点    3227      766      济南
# 176        787        324        玉溪       一般节点    1536     1941      广州
# 986       4069       1205        宁波       一般节点      96      114    呼和浩特
# 427        591        638        绥化       一般节点     235     1649      北京
# 429        591       1080        绥化       一般节点     180       52    呼和浩特
# 46          96        135      呼和浩特       一般节点    2549      836      沈阳
# 547         63         62        通辽       一般节点    1756     1067      北京
# 66         180         26      呼和浩特       一般节点   36272      133      太原
# 112        474        677       哈尔滨       一般节点    3227      195      济南
# 987       2473       1460        吉林       一般节点      96      117    呼和浩特
# 793        180         20      呼和浩特       一般节点     474      359     哈尔滨
# 320         96        134      呼和浩特       一般节点    3643      893      武汉
# 449        787        316        玉溪       一般节点   36422      394      天津
# 292         63          6        通辽       一般节点    2841      418      郑州
#
#      to_level      traffic     bandwidth
# 421      一般节点  50790049953  1.000000e+11
# 161      网络核心  48085896120  1.000000e+11
# 42       网络核心  48077485179  1.000000e+11
# 931      网络核心  52060473597  1.000000e+11
# 157      一般节点  50954337724  1.000000e+11
# 724      一般节点  50994646887  1.000000e+11
# 980      一般节点  49837582425  1.000000e+11
# 86       一般节点  49248544673  1.000000e+11
# 173      一般节点  49399787960  1.000000e+11
# 174      网络核心  51407063255  1.000000e+11
# 542      一般节点  49716409605  1.000000e+11
# 416      一般节点  50126205393  1.000000e+11
# 154      网络核心  50161021515  1.000000e+11
# 64       网络核心  51722488070  1.000000e+11
# 644      一般节点  51384841448  1.000000e+11
# 398      网络核心  50733378641  1.000000e+11
# 447      一般节点  49557001334  1.000000e+11
# 1035     一般节点  50638071722  1.000000e+11
# 669      网络核心  50318390185  1.000000e+11
# 109      网络核心  50446722135  1.000000e+11
# 304      网络核心  50504074996  1.000000e+11
# 388      一般节点  49289354051  1.000000e+11
# 125      网络核心  50242784823  1.000000e+11
# 16       网络核心  48476552334  1.000000e+11
# 315      网络核心  50502305163  1.000000e+11
# 280      网络核心  49512830312  1.000000e+11
# 50       网络核心  51538493830  1.000000e+11
# 40       网络核心  48814619370  1.000000e+11
# 375      网络核心  50424883915  1.000000e+11
# 167      网络核心  51033155364  1.000000e+11
# 380      网络核心  51078772989  1.000000e+11
# 371      网络核心  49027966353  1.000000e+11
# 1086     网络核心  51411580502  1.000000e+11
# 1018     网络核心  48132652830  1.000000e+11
# 939      网络核心  49208374165  1.000000e+11
# 91       一般节点  50106121660  1.000000e+11
# 291      网络核心  49389391674  1.000000e+11
# 176      网络核心  48712502205  1.000000e+11
# 986      一般节点  49413180407  1.000000e+11
# 427      网络核心  50512261162  1.000000e+11
# 429      一般节点  49419561900  1.000000e+11
# 46       网络核心  48380335564  1.000000e+11
# 547      网络核心  49632977575  1.000000e+11
# 66       网络核心  51023900961  1.000000e+11
# 112      网络核心  51631856877  1.000000e+11
# 987      一般节点  50920098518  1.000000e+11
# 793      一般节点  50601340670  1.000000e+11
# 320      网络核心  48498103572  1.000000e+11
# 449      网络核心  50880826227  1.000000e+11
# 292      网络核心  51392218854  1.000000e+11

# %%
ybjd=data_before_sample.loc[data_before_sample['to_level']=='一般节点']
wlhx=data_before_sample.loc[data_before_sample['to_level']=='网络核心']
after_sample=pd.concat([ybjd.sample(17),wlhx.sample(33)])
after_sample
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 49          96        152      呼和浩特       一般节点      47      314      通辽
# 984       4360        468        南京       一般节点      96      108    呼和浩特
# 773       2473        762        吉林       一般节点     180       84    呼和浩特
# 441        591       1300        绥化       一般节点      47      252      通辽
# 9           47        252        通辽       一般节点      96      134    呼和浩特
# 404        474       1410       哈尔滨       一般节点   36036       54      长春
# 791        180        264      呼和浩特       一般节点     180      276    呼和浩特
# 100        474        422       哈尔滨       一般节点      96      141    呼和浩特
# 779         96        152      呼和浩特       一般节点     180      202    呼和浩特
# 328         96        158      呼和浩特       一般节点      47      427      通辽
# 59          96        391      呼和浩特       一般节点      47      417      通辽
# 1031       591         23        绥化       一般节点      96      152    呼和浩特
# 392        474       1228       哈尔滨       一般节点      96      134    呼和浩特
# 806        180         20      呼和浩特       一般节点     474      670     哈尔滨
# 559         96        102      呼和浩特       一般节点   36036       52      长春
# 924       2473       1043        吉林       一般节点      47      427      通辽
# 339        180         18      呼和浩特       一般节点      47      241      通辽
# 143        591         96        绥化       一般节点    3443      101      青岛
# 321         96        135      呼和浩特       一般节点    2050      553     石家庄
# 133        591         13        绥化       一般节点   36422      324      天津
# 701       2473        803        吉林       一般节点    2194      406      唐山
# 152        591        638        绥化       一般节点    2194      264      唐山
# 291         47        427        通辽       一般节点    3227      766      济南
# 324         96        152      呼和浩特       一般节点    3643      559      武汉
# 349        180         52      呼和浩特       一般节点    3227      449      济南
# 114        474        682       哈尔滨       一般节点    1536      585      广州
# 1047       180         52      呼和浩特       一般节点    2701       71      大连
# 1059        47        252        通辽       一般节点    1997      250      天津
# 490         47        243        通辽       一般节点    1385     2778      广州
# 353        180        188      呼和浩特       一般节点    1536     2274      广州
# 660         63        224        通辽       一般节点    2701       71      大连
# 346        180         38      呼和浩特       一般节点    2549     1487      沈阳
# 452        787        325        玉溪       一般节点    2701      181      大连
# 154        591       1080        绥化       一般节点     235     1621      北京
# 587         96        141      呼和浩特       一般节点    3213      246      重庆
# 427        591        638        绥化       一般节点     235     1649      北京
# 142        591         64        绥化       一般节点   36272      105      太原
# 643        474        422       哈尔滨       一般节点    2549      835      沈阳
# 6           47        249        通辽       一般节点    1997       85      天津
# 62          96        460      呼和浩特       一般节点    1997      729      天津
# 1093       591        586        绥化       一般节点    1536       86    鄂尔多斯
# 667      36539       1140        杭州       一般节点    3227      781      济南
# 119        474       1246       哈尔滨       一般节点    3227      705      济南
# 717       2473       1043        吉林       一般节点   36422      324      天津
# 365        180        260      呼和浩特       一般节点    1756      788      北京
# 276         47         74        通辽       一般节点    4561     1033      成都
# 718       4360        472        南京       一般节点    1385     1490      广州
# 58          96        383      呼和浩特       一般节点    5242      783      西安
# 1           47         74        通辽       一般节点    1756      776      北京
# 993      36036         18        长春       一般节点    2194      450      唐山
#
#      to_level      traffic     bandwidth
# 49       一般节点  51981076188  1.000000e+11
# 984      一般节点  51700762978  1.000000e+11
# 773      一般节点  49702910101  1.000000e+11
# 441      一般节点  50817586398  1.000000e+11
# 9        一般节点  50256475808  1.000000e+11
# 404      一般节点  49488245045  1.000000e+11
# 791      一般节点  49965760241  1.000000e+11
# 100      一般节点  48084671443  1.000000e+11
# 779      一般节点  51162997127  1.000000e+11
# 328      一般节点  49385366171  1.000000e+11
# 59       一般节点  51570663870  1.000000e+11
# 1031     一般节点  51357214855  1.000000e+11
# 392      一般节点  51278220999  1.000000e+11
# 806      一般节点  50581993828  1.000000e+11
# 559      一般节点  49483965391  1.000000e+11
# 924      一般节点  50311375989  1.000000e+11
# 339      一般节点  51793025548  1.000000e+11
# 143      网络核心  51199279798  1.000000e+11
# 321      网络核心  51921872375  1.000000e+11
# 133      网络核心  50085514419  1.000000e+11
# 701      网络核心  48906180396  1.000000e+11
# 152      网络核心  49178187887  1.000000e+11
# 291      网络核心  49389391674  1.000000e+11
# 324      网络核心  49665987866  1.000000e+11
# 349      网络核心  47569937466  1.000000e+11
# 114      网络核心  50262691915  1.000000e+11
# 1047     网络核心  51851486412  1.000000e+11
# 1059     网络核心  50358481161  1.000000e+11
# 490      网络核心  50075073640  1.000000e+11
# 353      网络核心  50649912010  1.000000e+11
# 660      网络核心  50555895575  1.000000e+11
# 346      网络核心  49270219035  1.000000e+11
# 452      网络核心  49891276242  1.000000e+11
# 154      网络核心  50161021515  1.000000e+11
# 587      网络核心  47941844052  1.000000e+11
# 427      网络核心  50512261162  1.000000e+11
# 142      网络核心  51256753219  1.000000e+11
# 643      网络核心  50003053222  1.000000e+11
# 6        网络核心  50499586948  1.000000e+11
# 62       网络核心  49455021334  1.000000e+11
# 1093     网络核心  47929885030  1.000000e+11
# 667      网络核心  49721314562  1.000000e+11
# 119      网络核心  50954049859  1.000000e+11
# 717      网络核心  50594312992  1.000000e+11
# 365      网络核心  48917626581  1.000000e+11
# 276      网络核心  50819524115  1.000000e+11
# 718      网络核心  48195505413  1.000000e+11
# 58       网络核心  50609333179  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 993      网络核心  49826827167  1.000000e+11

# %%
def systematic_sampling(data, sample_size, random_start=True):
    """系统抽样方法"""
    n = len(data)
    k = n // sample_size 
    
    if random_start:
        start = np.random.randint(0, k)
    else:
        start = 0
    
    # 生成抽样索引
    indices = [start + i * k for i in range(sample_size) if (start + i * k) < n]
    
    return data.iloc[indices].reset_index(drop=True)


systematic_sample = systematic_sampling(data_before_sample, 50, random_start=True)
systematic_sample
# Out:
#     from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0         47         74        通辽       一般节点    1756      776      北京
# 1         47        260        通辽       一般节点    2549      835      沈阳
# 2         63         62        通辽       一般节点   36422      394      天津
# 3         96         99      呼和浩特       一般节点    1257      560      上海
# 4         96        134      呼和浩特       一般节点      47      252      通辽
# 5         96        346      呼和浩特       一般节点    1257      138      上海
# 6        180         28      呼和浩特       一般节点    1385      133      广州
# 7        180        188      呼和浩特       一般节点   36422      350      天津
# 8        180        256      呼和浩特       一般节点    1129      171      上海
# 9        474        467       哈尔滨       一般节点    1257      174      上海
# 10       474        683       哈尔滨       一般节点    1997       84      天津
# 11       474       1389       哈尔滨       一般节点    1756     1127      北京
# 12       591         23        绥化       一般节点      63        6      通辽
# 13       591        558        绥化       一般节点   36036      499      长春
# 14       591       1274        绥化       一般节点    1129      203      上海
# 15       787        307        玉溪       一般节点    4953      686      贵阳
# 16        47        240        通辽       一般节点    3213      246      重庆
# 17        47        314        通辽       一般节点    3213      589      重庆
# 18        63         70        通辽       一般节点    3643      831      武汉
# 19        96        105      呼和浩特       一般节点    2473      804      吉林
# 20        96        141      呼和浩特       一般节点    2050      391     石家庄
# 21        96        391      呼和浩特       一般节点      96      120    呼和浩特
# 22       180         36      呼和浩特       一般节点    2841      519      郑州
# 23       180        202      呼和浩特       一般节点    1257      536      上海
# 24       180        272      呼和浩特       一般节点     474      472     哈尔滨
# 25       474        472       哈尔滨       一般节点    3643      902      武汉
# 26       474        682       哈尔滨       一般节点    1997       85      天津
# 27       474       1389       哈尔滨       一般节点     235      106      北京
# 28       591         23        绥化       一般节点    2701       71      大连
# 29       591        558        绥化       一般节点     180       20    呼和浩特
# 30       591       1250        绥化       一般节点    3227      468      济南
# 31       787         60        玉溪       一般节点      47      314      通辽
# 32       787        418        玉溪       一般节点   36422      124      天津
# 33        47        258        通辽       一般节点     235     1958      北京
# 34        47        258        通辽       一般节点    1997       84      天津
# 35        63         58        通辽       一般节点    1756     1127      北京
# 36        63        282        通辽       一般节点      63        6      通辽
# 37        63         12        通辽       一般节点    2994      430      洛阳
# 38       591         23        绥化       一般节点    3443      117      青岛
# 39        47        417        通辽       一般节点   36422      394      天津
# 40      2473        803        吉林       一般节点    2194      406      唐山
# 41      4069       1195        宁波       一般节点      96      134    呼和浩特
# 42        96        134      呼和浩特       一般节点     180       98    呼和浩特
# 43       180         52      呼和浩特       一般节点     474      682     哈尔滨
# 44       474        422       哈尔滨       一般节点     591      638      绥化
# 45      2473        946        吉林       一般节点    2050      331     石家庄
# 46        63          6        通辽       一般节点    2050      269     石家庄
# 47      4069       1205        宁波       一般节点      96      114    呼和浩特
# 48       591         23        绥化       一般节点      96      152    呼和浩特
# 49        47        417        通辽       一般节点    1756     1029      北京
#
#    to_level      traffic     bandwidth
# 0      网络核心  50056871412  1.000000e+11
# 1      网络核心  50220958279  1.000000e+11
# 2      网络核心  50322780029  1.000000e+11
# 3      网络核心  49753614568  1.000000e+11
# 4      一般节点  49416652053  1.000000e+11
# 5      网络核心  47759033178  1.000000e+11
# 6      网络核心  52798223188  1.000000e+11
# 7      网络核心  49047066099  1.000000e+11
# 8      网络核心  49512421445  1.000000e+11
# 9      网络核心  49987703744  1.000000e+11
# 10     网络核心  49446798762  1.000000e+11
# 11     网络核心  48259332712  1.000000e+11
# 12     一般节点  49462640634  1.000000e+11
# 13     一般节点  49953028308  1.000000e+11
# 14     网络核心  49321244844  1.000000e+11
# 15     一般节点  49399787960  1.000000e+11
# 16     网络核心  47105527982  1.000000e+11
# 17     网络核心  48453452651  1.000000e+11
# 18     网络核心  50635697563  1.000000e+11
# 19     一般节点  51224734473  1.000000e+11
# 20     网络核心  49814111100  1.000000e+11
# 21     一般节点  51609945530  1.000000e+11
# 22     网络核心  49615778204  1.000000e+11
# 23     网络核心  50231972607  1.000000e+11
# 24     一般节点  49398387251  1.000000e+11
# 25     网络核心  50470657254  1.000000e+11
# 26     网络核心  50053473543  1.000000e+11
# 27     网络核心  50173065722  1.000000e+11
# 28     网络核心  50009822342  1.000000e+11
# 29     一般节点  48364223310  1.000000e+11
# 30     网络核心  50478302588  1.000000e+11
# 31     一般节点  49484495071  1.000000e+11
# 32     网络核心  50721158025  1.000000e+11
# 33     网络核心  48574009525  1.000000e+11
# 34     网络核心  50060087433  1.000000e+11
# 35     网络核心  51132553467  1.000000e+11
# 36     一般节点  49489299594  1.000000e+11
# 37     网络核心  49165115912  1.000000e+11
# 38     网络核心  50873359555  1.000000e+11
# 39     网络核心  50110808318  1.000000e+11
# 40     网络核心  48906180396  1.000000e+11
# 41     一般节点  50099141709  1.000000e+11
# 42     一般节点  51993612239  1.000000e+11
# 43     一般节点  50713290427  1.000000e+11
# 44     一般节点  51214123797  1.000000e+11
# 45     网络核心  50778035219  1.000000e+11
# 46     网络核心  49208374165  1.000000e+11
# 47     一般节点  49413180407  1.000000e+11
# 48     一般节点  51357214855  1.000000e+11
# 49     网络核心  49459363742  1.000000e+11

# %%
def cluster_sampling(data, cluster_column, n_clusters, random_state=None):
    """整群抽样方法"""
    if random_state is not None:
        np.random.seed(random_state)
    
    # 获取所有唯一的群
    unique_clusters = data[cluster_column].unique()
    
    # 随机选择指定数量的群
    selected_clusters = np.random.choice(unique_clusters, n_clusters, replace=False)
    
    # 抽取选中群的所有样本
    cluster_sample = data[data[cluster_column].isin(selected_clusters)]
    
    return cluster_sample.reset_index(drop=True)


# 以from_city为依据分组进行整群抽样
cluster_sample = cluster_sampling(data_before_sample, 'from_city', 2, random_state=42)
cluster_sample
# Out:
#    from_dev  from_port from_city from_level  to_dev  to_port to_city to_level  \
# 0      4360        472        南京       一般节点    1385     1490      广州     网络核心
# 1      4360        468        南京       一般节点    3443      117      青岛     网络核心
# 2      3757        122        福州       一般节点      96      407    呼和浩特     一般节点
# 3      4360        472        南京       一般节点    1997      251      天津     网络核心
# 4      4360        468        南京       一般节点    1997      464      天津     网络核心
# 5      4360        472        南京       一般节点      63      286      通辽     一般节点
# 6      4360        468        南京       一般节点      96      108    呼和浩特     一般节点
#
#        traffic     bandwidth
# 0  48195505413  1.000000e+11
# 1  49458752996  1.000000e+11
# 2  47597054356  1.000000e+11
# 3  48414179107  1.000000e+11
# 4  49145116989  1.000000e+11
# 5  49837582425  1.000000e+11
# 6  51700762978  1.000000e+11
